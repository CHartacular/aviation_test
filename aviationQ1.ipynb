# %%
import pandas as pd
av_data = "/Users/chart/Desktop/Aviation Delays.csv"
av = pd.read_csv(av_data)

av.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2018       9      F9  Frontier Airlines Inc.     PBI
# 1  2018       9      F9  Frontier Airlines Inc.     PDX
# 2  2018       9      F9  Frontier Airlines Inc.     PHL
# 3  2018       9      F9  Frontier Airlines Inc.     PHX
# 4  2018       9      F9  Frontier Airlines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...          8.0        3.0
# 1               Portland, OR: Portland International         69.0       24.0
# 2       Philadelphia, PA: Philadelphia International        321.0      113.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International        103.0       25.0
# 4           Pittsburgh, PA: Pittsburgh International         32.0        9.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0        0.85         0.0         ...                   0.0              1.65
# ...

# %%
list(av.columns.values)
# Out:
# ['year',
#  ' month',
#  'carrier',
#  'carrier_name',
#  'airport',
#  'airport_name',
#  'arr_flights',
#  'arr_del15',
#  'carrier_ct',
#  'weather_ct',
#  'nas_ct',
#  'security_ct',
#  'late_aircraft_ct',
#  'arr_cancelled',
#  'arr_diverted',
#  'arr_delay',
#  'carrier_delay',
#  'weather_delay',
#  'nas_delay',
#  'security_delay',
#  'late_aircraft_delay']

# %%
pd.set_option('display.max_rows', 500)
av.groupby('airport').weather_ct.sum()
# Out:
# airport
# ABE      5.15
# ABI      6.27
# ABQ     13.39
# ABR      0.00
# ABY      1.03
# ACK      2.88
# ACT      1.53
# ACV      1.00
# ACY      1.81
# ADK      0.00
# ADQ      0.00
# AEX      5.18
# AGS      4.51
# ALB     13.30
# ALO      1.43
# AMA      6.85
# ANC      1.26
# APN      0.00
# ASE      3.51
# ATL    174.81
# ATW      0.43
# AUS     37.20
# AVL      8.66
# AVP      2.70
# AZA      1.08
# AZO      5.36
# BDL     18.81
# BET      1.97
# BFF      0.00
# BFL      0.51
# BGM      0.87
# BGR      0.97
# BHM     19.04
# BIL      0.00
# BIS      1.11
# BJI      1.00
# BKG      0.00
# BLI      0.00
# BLV      0.00
# BMI      4.45
# BNA     39.87
# BOI      6.43
# BOS     75.97
# BPT      1.92
# BQK      0.00
# BQN      1.89
# BRD      0.91
# BRO      2.70
# BRW      0.00
# BTM      0.00
# BTR     14.71
# BTV      6.96
# BUF     13.82
# BUR      0.20
# BWI     45.45
# BZN      1.79
# CAE      4.40
# CAK     11.35
# CDC      0.00
# CDV      0.00
# CGI      0.00
# ...

# %%
av.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2018       9      F9  Frontier Airlines Inc.     PBI
# 1  2018       9      F9  Frontier Airlines Inc.     PDX
# 2  2018       9      F9  Frontier Airlines Inc.     PHL
# 3  2018       9      F9  Frontier Airlines Inc.     PHX
# 4  2018       9      F9  Frontier Airlines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...          8.0        3.0
# 1               Portland, OR: Portland International         69.0       24.0
# 2       Philadelphia, PA: Philadelphia International        321.0      113.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International        103.0       25.0
# 4           Pittsburgh, PA: Pittsburgh International         32.0        9.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0        0.85         0.0         ...                   0.0              1.65
# ...

# %%
av_mean = av.groupby('carrier_name').arr_delay.agg(['count', 'mean', 'min', 'max'])

# %%
av_mean.sort_values(by=['mean'])
# Out:
#                           count         mean    min       max
# carrier_name
# Allegiant Air               115   557.365217    0.0    7931.0
# Hawaiian Airlines Inc.       18  1572.833333   15.0   11686.0
# Alaska Airlines Inc.         71  1866.000000    0.0   39828.0
# Envoy Air                   131  1942.305344    0.0   56983.0
# Endeavor Air Inc.           104  2366.692308    0.0   49920.0
# ExpressJet Airlines Inc.    105  2468.485714    0.0   49917.0
# PSA Airlines Inc.            93  2647.430108    0.0   69125.0
# Frontier Airlines Inc.       87  2707.252874   23.0   42958.0
# SkyWest Airlines Inc.       229  2920.703057    0.0  110534.0
# Republic Airline             84  3393.142857    0.0   41433.0
# Delta Air Lines Inc.        144  3571.923611    0.0  133589.0
# Mesa Airlines Inc.           98  3670.561224    0.0   74092.0
# Spirit Air Lines             42  3751.500000    0.0   16460.0
# JetBlue Airways              69  4900.898551    0.0   78025.0
# ...
